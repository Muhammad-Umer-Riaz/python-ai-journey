# %% [markdown]
# # Chapter 10: READING AND WRITING FILES
#
# ### Chapter FollowThrough

# %% [markdown]
# #### Joining Paths

# %%
from pathlib import Path
# Store results in variables first
path1 = Path('spam') / 'bacon' / 'eggs'
path2 = Path('spam') / Path('bacon/eggs')
path3 = Path('spam') / Path('bacon', 'eggs')

# Then print them
print(path1)
print(path2)
print(path3)
# Out:
# spam\bacon\eggs
# spam\bacon\eggs
# spam\bacon\eggs

# %% [markdown]
# #### Accessing the Current Working Directory

# %%
print(f"Current working directory: {Path.cwd()}")
# Out:
# Current working directory: e:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files

# %% [markdown]
# #### Accessing the Home Directory

# %%
print(f"Home directory: {Path.home()}")
# Out:
# Home directory: C:\Users\muham

# %% [markdown]
# #### Handling Absolute and Relative Paths

# %%
print(f"Is the path absolute? {Path.cwd().is_absolute()}")
print(f"Is the path absolute? {Path('spam/bacon/eggs').is_absolute()}")
# Out:
# Is the path absolute? True
# Is the path absolute? False

# %% [markdown]
# #### Getting the Parts of a Filepath

# %%
path = Path(r"E:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files\chapter-10-exercises.ipynb")
print(f"Drive: {path.drive}")
print(f"Root: {path.root}") #
print(f"Anchor: {path.anchor}")
print(f"Parent: {path.parent}")
print(f"Name: {path.name}")
print(f"Stem: {path.stem}")
print(f"Suffix: {path.suffix}")
# Out:
# Drive: E:
# Root: \
# Anchor: E:\
# Parent: E:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files
# Name: chapter-10-exercises.ipynb
# Stem: chapter-10-exercises
# Suffix: .ipynb

# %% [markdown]
# #### Splitting a File Path into Parts

# %%
print(f"Parts: {path.parts}")
# Out:
# Parts: ('E:\\', 'VS Code', 'python-ai-journey', 'automate-the-boring-stuff', 'chapter-10-reading-and-writing-files', 'chapter-10-exercises.ipynb')

# %% [markdown]
# #### Finding File Sizes and Timestamps

# %%
import time

print(f"File statistics: {path.stat()}")
print(f"File size: {path.stat().st_size} bytes")
print(f"Last modified: {time.ctime(path.stat().st_mtime)}")
print(f"Last accessed: {time.ctime(path.stat().st_atime)}")
print(f"Creation time: {time.ctime(path.stat().st_birthtime)}")
# Out:
# File statistics: os.stat_result(st_mode=33206, st_ino=844424930156051, st_dev=16864911754850970121, st_nlink=1, st_uid=0, st_gid=0, st_size=4157, st_atime=1772718551, st_mtime=1772715665, st_ctime=1772714147)
# File size: 4157 bytes
# Last modified: Thu Mar  5 15:01:05 2026
# Last accessed: Thu Mar  5 15:49:11 2026
# Creation time: Thu Mar  5 14:35:47 2026

# %% [markdown]
# #### Finding Files Using Glob Patterns

# %%
print(f"All files in current directory: {list(Path.cwd().glob('*'))}")

python_ai_journey_path = Path(r"E:\VS Code\python-ai-journey")
# 1. Just your notebooks (exclude .git folder)
notebooks = list(python_ai_journey_path.rglob('*.ipynb'))
print(f"\nYour notebooks: {len(notebooks)}")
for nb in notebooks:
    print(f"  - {nb.parent.name}/{nb.name}")

# 2. Just data files
data_files = list(python_ai_journey_path.rglob('*.csv')) + list(python_ai_journey_path.rglob('*.txt'))
print(f"\nData files: {data_files}")

# 3. Count files by type
py_files = list(python_ai_journey_path.rglob('*.py'))
ipynb_files = list(python_ai_journey_path.rglob('*.ipynb'))
md_files = list(python_ai_journey_path.rglob('*.md'))
csv_files = list(python_ai_journey_path.rglob('*.csv'))
other_files = [f for f in python_ai_journey_path.rglob('*') if f.is_file() and f.suffix not in ['.py', '.ipynb', '.md', '.csv', '.txt']]

print(f"\nFile counts:")
print(f"  Python files: {len(py_files)}")
print(f"  Notebooks: {len(ipynb_files)}")
print(f"  Text files: {len(data_files)}")
print(f"  Markdown: {len(md_files)}")
print(f"  CSV files: {len(csv_files)}")
print(f"  Other files: {len(other_files)}")
# Out:
# All files in current directory: [WindowsPath('e:/VS Code/python-ai-journey/automate-the-boring-stuff/chapter-10-reading-and-writing-files/chapter-10-exercises.ipynb')]
#
# Your notebooks: 10
#   - chapter-01-python-basics/chapter-01-exercises.ipynb
#   - chapter-02-if-else-and-flow-control/chapter-02-exercises.ipynb
#   - chapter-03-loops/chapter-03-exercises.ipynb
#   - chapter-04-functions/chapter-04-exercises.ipynb
#   - chapter-05-debugging/chapter-05-exercises.ipynb
#   - chapter-06-lists/chapter-06-exercises.ipynb
#   - chapter-07-disctionaries-and-structuring-data/chapter-07-disctionaries-and-structuring-data.ipynb
#   - chapter-08-strings-and-text-editing/chapter-08-exercises.ipynb
#   - chapter-09-text-pattern-matching-with-regular-expression/chapter-09-exercises.ipynb
#   - chapter-10-reading-and-writing-files/chapter-10-exercises.ipynb
#
# ...

# %% [markdown]
# ## Generate Random Quiz Files
#
# Say you’re a geography teacher with 35 students in your class and you want to give a pop quiz on EU country capitals. Alas, your class has a few bad eggs in it, and you can’t trust the students not to cheat. You’d like to randomize the order of questions so that each quiz is unique, making it impossible for anyone to crib answers from anyone else.
#
# Here is what the program does:
#
# * Creates 35 different quizzes
# * Creates 45 multiple-choice questions for each quiz, in random order
# * Provides the correct answer and three random wrong answers for each question, in random order
# * Writes the quizzes to 35 text files
# * Writes the answer keys to 35 text files
#
# This means the code will need to do the following:
#
# * Store the states and their capitals in a dictionary.
# * Call open(), write(), and close() for the quiz and answer key text files.
# * Use random.shuffle() to randomize the order of the questions and multiple-choice options.

# %%
# Generate Random Quiz Files

# randomQuizGenerator.py - Creates quizzes with questions and answers in
# random order, along with the answer key

# Step 1: Store the Quiz Data in a Dictionary

import random

# The quiz data. Keys are EU countries and values are their capitals.

capitals = {
    'Albania': 'Tirana',
    'Andorra': 'Andorra la Vella',
    'Austria': 'Vienna',
    'Belarus': 'Minsk',
    'Belgium': 'Brussels',
    'Bosnia and Herzegovina': 'Sarajevo',
    'Bulgaria': 'Sofia',
    'Croatia': 'Zagreb',
    'Cyprus': 'Nicosia',
    'Czech Republic': 'Prague',
    'Denmark': 'Copenhagen',
    'Estonia': 'Tallinn',
    'Finland': 'Helsinki',
    'France': 'Paris',
    'Germany': 'Berlin',
    'Greece': 'Athens',
    'Hungary': 'Budapest',
    'Iceland': 'Reykjavik',
    'Ireland': 'Dublin',
    'Italy': 'Rome',
    'Latvia': 'Riga',
    'Liechtenstein': 'Vaduz',
    'Lithuania': 'Vilnius',
    'Luxembourg': 'Luxembourg City',
    'Malta': 'Valletta',
    'Moldova': 'Chisinau',
    'Monaco': 'Monaco',
    'Montenegro': 'Podgorica',
    'Netherlands': 'Amsterdam',
    'North Macedonia': 'Skopje',
    'Norway': 'Oslo',
    'Poland': 'Warsaw',
    'Portugal': 'Lisbon',
    'Romania': 'Bucharest',
    'Russia': 'Moscow',
    'San Marino': 'San Marino',
    'Serbia': 'Belgrade',
    'Slovakia': 'Bratislava',
    'Slovenia': 'Ljubljana',
    'Spain': 'Madrid',
    'Sweden': 'Stockholm',
    'Switzerland': 'Bern',
    'Ukraine': 'Kyiv',
    'United Kingdom': 'London',
    'Vatican City': 'Vatican City'
}   

# Step 2: Set the directory path for quiz files
quiz_directory = Path(r'E:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files\EU-capitals-quiz')

# Generate 35 quiz files.
for quizNum in range(35):

# Step 3: Create the Quiz files
    quizFile = open(quiz_directory / f'capitalsquiz{quizNum + 1}.txt', 'w', encoding='utf-8')
    answerKeyFile = open(quiz_directory / f'capitalsquiz_answers{quizNum + 1}.txt', 'w', encoding='utf-8')

    # Write the header for the quiz.
    quizFile.write('Name:\n\nDate:\n\nPeriod:\n\n')
    quizFile.write((' ' * 20) + f'European Capitals Quiz (Form {quizNum + 1})')
    quizFile.write('\n\n')

    # Shuffle the order of the countries.
    countries = list(capitals.keys())
    random.shuffle(countries)

    # Step 4: Create the answer options
    # Loop through all 45 countries, making a question for each.
    for questionNum in range(45):
        # Get right and wrong answers.
        correctAnswer = capitals[countries[questionNum]]
        wrongAnswers = list(capitals.values())
        del wrongAnswers[wrongAnswers.index(correctAnswer)]
        wrongAnswers = random.sample(wrongAnswers, 3)
        answerOptions = wrongAnswers + [correctAnswer]
        random.shuffle(answerOptions)

        # Step 5: Write the quiz and the answer key to files
        quizFile.write(f'{questionNum + 1}. What is the capital of {countries[questionNum]}?\n')
        for i in range(4):
            quizFile.write(f"   {'ABCD'[i]}. {answerOptions[i]}\n")
        quizFile.write('\n')

        # Write the answer key to a file.
        answerKeyFile.write(f"{questionNum + 1}. {'ABCD'[answerOptions.index(correctAnswer)]}\n")
    
    # Close the files.
    quizFile.close()
    answerKeyFile.close()

# %% [markdown]
# ### Text File Combiner
# Let’s create a function named combine_two_text_files() that can combine the contents of two text files. The function takes three arguments: two filenames of text files whose contents should be read, and the filename of a third text file in which to write the combined contents.
#
# For example, if your function were named combine_two_text_files(), calling combine_two_text_files('spam.txt', 'eggs.txt', 'output.txt') would create a new file named output.txt with the contents of the spam.txt and eggs.txt files.

# %%
def clean_path(path_string):
    """Remove surrounding quotes from pasted file paths."""
    return path_string.strip('"\'')

print("Enter the path of the first text file:")
file1_input = input()
file1 = clean_path(file1_input)

if not Path(file1).is_file():
    print(f"Error: The file '{file1}' does not exist.")
    
print("Enter the path of the second text file:")
file2_input = input()
file2 = clean_path(file2_input)

if not Path(file2).is_file():
    print(f"Error: The file '{file2}' does not exist.")

print("Enter the directory where you want to save 'output.txt':")
dir_input = input()
save_dir = clean_path(dir_input)
save_path = Path(save_dir)

# Create the full output file path
output_file = save_path / 'output.txt'

if not save_path.exists():
    print(f"Error: The directory '{save_path}' does not exist.")
    
def combine_two_text_files(file1, file2, output_file):
    # Read the contents of the first file
    with open(file1, 'r', encoding='utf-8') as f1:
        content1 = f1.read()
    
    # Read the contents of the second file
    with open(file2, 'r', encoding='utf-8') as f2:
        content2 = f2.read()
    
    # Combine the contents
    combined_content = content1 + '\n' + content2

    # Write the combined contents to the output file
    with open(output_file, 'w', encoding='utf-8') as out_f:
        out_f.write(combined_content)

# Call the function
combine_two_text_files(file1, file2, output_file)
print(f"Files combined successfully! Saved to: {output_file}")
# Out:
# Enter the path of the first text file:
# Enter the path of the second text file:
# Enter the directory where you want to save 'output.txt':
# Files combined successfully! Saved to: E:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files\EU-capitals-quiz\output.txt

# %% [markdown]
# ### Zigzag File
#
# ```
# ********
#  ********
#   ********
#    ********
#     ********
#      ********
#       ********
#      ********
#     ********
#    ********
#   ********
#  ********
# ********
#  ********
#   ********
#    ********
#     ********
# ```
# Your friend sees this and decides they’d like to make it their (very long) email signature or save it for some other use. Re-create this program, except add a function named write_zigzag() that writes the zigzag text to a file named zigzag.txt instead of printing it to the screen. This way, you can email the text file to your friend so that they can store it on their computer.
#
# While the screen version goes on forever, your program should write only 1,000 lines of zigs and zags to the file. Remember to remove the time.sleep() call from the original Zigzag program, as you won’t need it for this project.

# %%
# Zigzag pattern of asterisks with file writing
# This code creates a zigzag pattern 1000 lines of asterisks and saves it to a text file.
# The pattern starts with X asterisks and shifts right by one space on the next line till shifts again till a limited column width is reached, and then it starts moving back.

def create_zigzag_pattern(num_lines, max_column_width, output_file):
    with open(output_file, 'w', encoding='utf-8') as f:
        # Create a list of positions: 0,1,2,...,max-1, max-2,...,1,0,1,2,...
        positions = []
        for i in range(max_column_width):
            positions.append(i)
        for i in range(max_column_width-2, 0, -1):
            positions.append(i)
        
        # Repeat the pattern
        for i in range(num_lines):
            pos = positions[i % len(positions)]
            line = (' ' * pos) + ('*' * 10) + '\n'
            f.write(line)

# Ask User for tParameters for the zigzag pattern
num_lines = int(input("Enter the number of lines for the zigzag pattern: "))
max_column_width = int(input("Enter the number of asterisks in each line: "))

# Ask user for output file directory and store the created zigzag pattern in a file named 'zigzag_pattern.txt'
output_dir_input = input("Enter the directory where you want to save 'zigzag_pattern.txt': ")
output_dir = clean_path(output_dir_input)

print(f"Creating zigzag pattern with {num_lines} lines and max width of {max_column_width} spaces...\n")

# Create the full output file path
output_path = Path(output_dir) / 'zigzag_pattern.txt'

# Create the zigzag pattern and write to file
create_zigzag_pattern(num_lines, max_column_width, str(output_path))

print(f"Zigzag pattern saved to: {output_path}\n")

# Display the pattern in the notebook as well
print("Zigzag Pattern (shown in notebook):")
print("-" * 40)
positions = []
for i in range(max_column_width):
    positions.append(i)
for i in range(max_column_width-2, 0, -1):
    positions.append(i)

for i in range(num_lines):
    pos = positions[i % len(positions)]
    line = (' ' * pos) + ('*' * 10)
    print(line)
# Out:
# Creating zigzag pattern with 100 lines and max width of 10 spaces...
#
# Zigzag pattern saved to: E:\VS Code\python-ai-journey\automate-the-boring-stuff\chapter-10-reading-and-writing-files\zigzag-pattern\zigzag_pattern.txt
#
# Zigzag Pattern (shown in notebook):
# ----------------------------------------
# **********
#  **********
#   **********
#    **********
#     **********
#      **********
#       **********
#        **********
#         **********
#          **********
#         **********
#        **********
#       **********
#      **********
#     **********
#    **********
#   **********
#  **********
# **********
#  **********
#   **********
#    **********
#     **********
#      **********
#       **********
#        **********
#         **********
#          **********
#         **********
#        **********
#       **********
#      **********
#     **********
#    **********
#   **********
#  **********
# **********
#  **********
#   **********
#    **********
# ...

# %% [markdown]
# ### Rock, Paper, Scissors with Saved Games
#
# The rock, paper, scissors game in Chapter 3 of Automate the Boring Stuff with Python records how many wins, losses, and ties the player has. But these stats are tracked only while the program is running. Using the shelve module, add the ability to save these stats and load them the next time the program runs.
#
# Note that if the program has never previously saved the game stats, the wins, losses, and ties should all default to 0. Otherwise, the program should load these numbers when it starts and update them after each game.

# %%
# Rock, Paper, Scissors with Saved Games

import random, sys, shelve, datetime

print('ROCK, PAPER, SCISSORS')

# These variables keep track of the number of wins, losses, and ties.
with shelve.open('rps_stats') as stats:
    wins = stats.get('wins', 0)
    losses = stats.get('losses', 0)
    ties = stats.get('ties', 0)
    game_history = stats.get('history', [])

while True:  # The main game loop
    print('%s Wins, %s Losses, %s Ties' % (wins, losses, ties))
    while True:  # The player input loop
        print('Enter your move: (r)ock (p)aper (s)cissors or (q)uit')
        player_move = input('>')
        if player_move == 'q':
             # CHANGED: Save stats before quitting instead of just sys.exit()
            with shelve.open('rps_stats') as stats:
                stats['wins'] = wins
                stats['losses'] = losses
                stats['ties'] = ties
                stats['history'] = game_history
            sys.exit()
        if player_move == 'r' or player_move == 'p' or player_move == 's':
            break  # Break out of the player input loop.
        print('Type one of r, p, s, or q.')

    # Display what the player chose:
    if player_move == 'r':
        print('ROCK versus...')
    elif player_move == 'p':
        print('PAPER versus...')
    elif player_move == 's':
        print('SCISSORS versus...')

    # Display what the computer chose:
    move_number = random.randint(1, 3)
    if move_number == 1:
        computer_move = 'r'
        print('ROCK')
    elif move_number == 2:
        computer_move = 'p'
        print('PAPER')
    elif move_number == 3:
        computer_move = 's'
        print('SCISSORS')

    # Display and record the win/loss/tie:
    if player_move == computer_move:
        print('It is a tie!')
        ties = ties + 1
    elif player_move == 'r' and computer_move == 's':
        print('You win!')
        wins = wins + 1
    elif player_move == 'p' and computer_move == 'r':
        print('You win!')
        wins = wins + 1
    elif player_move == 's' and computer_move == 'p':
        print('You win!')
        wins = wins + 1
    elif player_move == 'r' and computer_move == 'p':
        print('You lose!')
        losses = losses + 1
    elif player_move == 'p' and computer_move == 's':
        print('You lose!')
        losses = losses + 1
    elif player_move == 's' and computer_move == 'r':
        print('You lose!')
        losses = losses + 1
    # After determining result, store the game
    if player_move == computer_move:
        result = 'tie'
    elif (player_move == 'r' and computer_move == 's') or (player_move == 'p' and computer_move == 'r') or (player_move == 's' and computer_move == 'p'):
        result = 'win'
    else:
        result = 'loss'
    
    game_record = {
        'timestamp': str(datetime.datetime.now()),
        'player': player_move,
        'computer': computer_move,
        'result': result
    }
    game_history.append(game_record)
